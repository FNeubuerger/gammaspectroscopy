# %%
from glob import glob
from src.utils import *

# %%
get_isotopes_df()
# Out:
#    Isotope                                   Energies (keV)  \
# 0   Cs-137                                          [661.7]
# 1    Co-60                                 [1173.2, 1332.5]
# 2    I-131                                          [364.5]
# 3   Tc-99m                                          [140.5]
# 4   Ra-226                   [186.2, 609.3, 1120.3, 1764.5]
# 5   Th-232                           [338.3, 911.2, 2614.5]
# 6    U-238                                  [234.0, 1001.0]
# 7     K-40                                         [1460.8]
# 8   Am-241                                           [59.5]
# 9    Na-22                                  [511.0, 1274.5]
# 10  Eu-152                           [121.8, 344.3, 1408.0]
# 11  Eu-154  [123.1, 1274.4, 723.32, 1004.8, 873.18, 996.29]
#
#                               Notes
# 0            Decay product: Ba-137m
# 1        Dual gamma peaks for decay
# 2       Used in medical diagnostics
# 3   Widely used in nuclear medicine
# 4   Includes a complex decay series
# 5           Part of the decay chain
# 6      Decay includes radon progeny
# 7      Natural isotope in potassium
# 8         Common in smoke detectors
# 9        Positron annihilation peak
# 10               Multi-line emitter
# 11               Multi-line emitter

# %%
process_spectrum('Daten/2016-11-21_09-27-54_Summenspektrum.txt', verbose=True)
# Out:
# Peak at 661.391182 +- 0.804249 keV matched to Cs-137 at 661.7 keV with confidence 0.93
# Isotope Cs-137 identified with 100.00% of peaks matched
#                                        filename  \
# 0  Daten/2016-11-21_09-27-54_Summenspektrum.txt
#
#                                                 data               peaks  \
# 0        energy in keV  counts  counts_cleaned
# 0 ...  [9, 18, 258, 2278]
#
#                                           properties  \
# 0  {'prominences': [3805.0, 11180.8, 1012.5, 4600...
#
#                                calculated_polynomial  \
# 0  [2.17812347791993, 4.79180021167972, 74.493223...
#
#                                         fitted_peaks  \
# 0  [0.608+/-0.006, 4.8+/-1.2, 74.7+/-0.9, 661.4+/...
#
#                                    fitted_peaks_mean  \
# 0  [0.607826119222415, 4.76137307340245, 74.74694...
#
#                                     fitted_peaks_std identified_isotopes  \
# 0  [0.006208764434984402, 1.2061180759638828, 0.8...            [Cs-137]
#
#       identified_peaks           confidences matched     total_confidences
# 0  [661.3911816685418]  [0.9289302314797583]   [1.0]  [0.9289302314797583]

# %%
process_spectrum('Daten/2016-11-30_10-25-23_Summenspektrum.txt', prominence=500, verbose=True)
# Out:
# Peak at 59.217665 +- 0.536248 keV matched to Am-241 at 59.5 keV with confidence 0.87
# Isotope Am-241 identified with 100.00% of peaks matched
# Peak at 661.142187 +- 0.729641 keV matched to Cs-137 at 661.7 keV with confidence 0.75
# Isotope Cs-137 identified with 100.00% of peaks matched
# Peak at 1172.861204 +- 0.803157 keV matched to Co-60 at 1173.2 keV with confidence 0.91
# Isotope Co-60 identified with 50.00% of peaks matched
# Peak at 1332.254520 +- 0.810737 keV matched to Co-60 at 1332.5 keV with confidence 0.96
# Isotope Co-60 identified with 50.00% of peaks matched
#                                        filename  \
# 0  Daten/2016-11-30_10-25-23_Summenspektrum.txt
#
#                                                 data  \
# 0        energy in keV  counts  counts_cleaned
# 0 ...
#
#                         peaks  \
# 0  [8, 205, 2277, 4037, 4584]
#
#                                           properties  \
# 0  {'prominences': [76036.0, 586.6666666666667, 2...
#
#                                calculated_polynomial  \
# 0  [1.8877155171219202, 59.100266049198254, 661.1...
#
#                                         fitted_peaks  \
# 0  [1.77+/-0.31, 59.2+/-0.5, 661.1+/-0.7, 1172.9+...
#
#                                    fitted_peaks_mean  \
# 0  [1.7739589530030737, 59.21766506216845, 661.14...
#
#                                     fitted_peaks_std  \
# 0  [0.3051797519565299, 0.5362484348841594, 0.729...
#
#               identified_isotopes  \
# 0  [Am-241, Cs-137, Co-60, Co-60]
#
#                                     identified_peaks  \
# 0  [59.21766506216845, 661.1421870980955, 1172.86...
#
#                                          confidences               matched  \
# 0  [0.8705750929142133, 0.8085849158497767, 0.844...  [1.0, 1.0, 0.5, 0.5]
#
#                                    total_confidences
# 0  [0.8705750929142133, 0.8085849158497767, 0.422...

# %%
plot_spectrum_from_file('Daten/2016-11-30_10-25-23_Summenspektrum.txt')

# %%
files = glob('Daten/*.txt')
len(files)
# Out:
# 1246

# %%
results_df = pd.concat([process_spectrum(file, prominence=500, rel_height=0.5, width=5, tolerance=0.7) for file in files], ignore_index=True)
results_df.head()
# Out:
#                                        filename  \
# 0  Daten\2016-11-21_09-27-54_Summenspektrum.txt
# 1  Daten\2016-11-24_07-16-40_Summenspektrum.txt
# 2  Daten\2016-11-25_12-59-15_Summenspektrum.txt
# 3  Daten\2016-11-28_07-17-31_Summenspektrum.txt
# 4  Daten\2016-11-29_08-48-54_Summenspektrum.txt
#
#                                                 data  \
# 0        energy in keV  counts  counts_cleaned
# 0 ...
# 1        energy in keV  counts  counts_cleaned
# 0 ...
# 2        energy in keV  counts  counts_cleaned
# 0 ...
# 3        energy in keV  counts  counts_cleaned
# 0 ...
# 4        energy in keV  counts  counts_cleaned
# 0 ...
#
#                                 peaks  \
# 0                [18, 258, 293, 2278]
# 1  [21, 33, 259, 293, 393, 638, 2278]
# 2                         [259, 2277]
# 3                          [15, 2278]
# 4                              [2277]
#
#                                           properties  \
# 0  {'prominences': [11180.8, 1012.5, 528.0, 4600....
# 1  {'prominences': [3138.272727272727, 894.545454...
# 2  {'prominences': [625.6842105263157, 4247.10526...
# 3  {'prominences': [4988.25, 1501.5], 'left_bases...
# 4  {'prominences': [2474.0], 'left_bases': [273],...
#
#                                calculated_polynomial  \
# 0  [4.79180021167972, 74.49322393286693, 84.65855...
# 1  [5.66302782423073, 9.14794844759017, 74.783660...
# 2             [74.78366015242995, 661.1142229767994]
# 3            [3.9205736164442504, 661.4048874141486]
# 4                                [661.1142229767994]
#
#                                         fitted_peaks  \
# 0   [4.8+/-1.2, 74.7+/-0.9, 84.7+/-0.8, 661.4+/-0.8]
# 1  [5.5+/-1.1, 9.0+/-1.3, 74.7+/-0.8, 84.7+/-0.5,...
# 2                          [74.7+/-0.6, 661.2+/-0.7]
# 3                           [3.8+/-1.1, 661.4+/-0.8]
# 4                                      [661.2+/-0.7]
#
#                                    fitted_peaks_mean  \
# 0  [4.76137307340245, 74.74694125621012, 84.71173...
# 1  [5.542068447473121, 9.012225287591614, 74.7399...
# 2             [74.68331556273748, 661.2150415767584]
# 3            [3.8043102161525417, 661.3668209392551]
# 4                                [661.2179912953839]
#
#                                     fitted_peaks_std identified_isotopes  \
# 0  [1.2061180759638828, 0.8994092399012966, 0.798...            [Cs-137]
# 1  [1.0552481992968843, 1.327251955969061, 0.8109...    [Ra-226, Cs-137]
# 2            [0.6374344646350101, 0.731104329465915]            [Cs-137]
# 3            [1.148171616070695, 0.7782814506475919]            [Cs-137]
# 4                               [0.7250499465652561]            [Cs-137]
#
#                          identified_peaks  \
# 0                     [661.3911816685418]
# 1  [184.9841847636407, 661.4299209577953]
# 2                     [661.2150415767584]
# 3                     [661.3668209392551]
# 4                     [661.2179912953839]
#
#                                 confidences      matched  \
# 0                      [0.9289302314797583]        [1.0]
# 1  [0.7876719183300314, 0.8673736514000012]  [0.25, 1.0]
# 2                      [0.8025197630444382]        [1.0]
# 3                      [0.9124399268619411]        [1.0]
# 4                      [0.8017364075040307]        [1.0]
#
#                            total_confidences
# 0                       [0.9289302314797583]
# 1  [0.19691797958250784, 0.8673736514000012]
# 2                       [0.8025197630444382]
# 3                       [0.9124399268619411]
# 4                       [0.8017364075040307]

# %%
results_df.drop(columns=['data', 'properties', 'fitted_peaks']).to_parquet('results_prominence=500_rel_height=0.5_width=5_tolerance=0.7.pq')
