# %%
from glob import glob
from src.utils import *

# %%
get_isotopes_df()
# Out:
#    Isotope                                   Energies (keV)  \
# 0   Cs-137                                          [661.7]
# 1    Co-60                                 [1173.2, 1332.5]
# 2    I-131                                          [364.5]
# 3   Tc-99m                                          [140.5]
# 4   Ra-226                   [186.2, 609.3, 1120.3, 1764.5]
# 5   Th-232                           [338.3, 911.2, 2614.5]
# 6    U-238                                  [234.0, 1001.0]
# 7     K-40                                         [1460.8]
# 8   Am-241                                           [59.5]
# 9    Na-22                                  [511.0, 1274.5]
# 10  Eu-152                           [121.8, 344.3, 1408.0]
# 11  Eu-154  [123.1, 1274.4, 723.32, 1004.8, 873.18, 996.29]
#
#                               Notes
# 0            Decay product: Ba-137m
# 1        Dual gamma peaks for decay
# 2       Used in medical diagnostics
# 3   Widely used in nuclear medicine
# 4   Includes a complex decay series
# 5           Part of the decay chain
# 6      Decay includes radon progeny
# 7      Natural isotope in potassium
# 8         Common in smoke detectors
# 9        Positron annihilation peak
# 10               Multi-line emitter
# 11               Multi-line emitter

# %%
process_spectrum('Daten/2016-11-21_09-27-54_Summenspektrum.txt', verbose=True)
# Out:
# Peak at 661.388601 +- 0.820614 keV matched to Cs-137 at 661.7 keV with confidence 0.93
# Isotope Cs-137 identified with 100.00% of peaks matched
#                                        filename  \
# 0  Daten/2016-11-21_09-27-54_Summenspektrum.txt
#
#                                                 data               peaks  \
# 0        energy in keV  counts
# 0             -0.4...  [9, 18, 259, 2278]
#
#                                           properties  \
# 0  {'prominences': [3805.0, 11790.0, 1572.0, 4551...
#
#                                calculated_polynomial  \
# 0  [2.17812347791993, 4.79180021167972, 74.783660...
#
#                                       fitted_peaks  \
# 0  [2.2+/-0.5, 4.8+/-1.3, 74.7+/-1.5, 661.4+/-0.8]
#
#                                    fitted_peaks_mean  \
# 0  [2.1949337017004584, 4.760360102175254, 74.747...
#
#                                     fitted_peaks_std identified_isotopes  \
# 0  [0.4716261301219222, 1.2607007423117536, 1.515...            [Cs-137]
#
#             confidences matched     total_confidences
# 0  [0.9305318283386198]   [1.0]  [0.9305318283386198]

# %%
process_spectrum('Daten/2016-11-30_10-25-23_Summenspektrum.txt', prominence=500, verbose=True)
# Out:
# Peak at 122.488298 +- 3.560845 keV matched to Eu-152 at 121.8 keV with confidence 0.98
# Isotope Eu-152 not sufficiently identified
# Peak at 122.488298 +- 3.560845 keV matched to Eu-154 at 123.1 keV with confidence 0.99
# Isotope Eu-154 not sufficiently identified
# Peak at 661.141015 +- 0.733836 keV matched to Cs-137 at 661.7 keV with confidence 0.75
# Isotope Cs-137 identified with 100.00% of peaks matched
# Peak at 1172.884311 +- 0.868520 keV matched to Co-60 at 1173.2 keV with confidence 0.94
# Isotope Co-60 identified with 50.00% of peaks matched
# Peak at 1332.252655 +- 0.844322 keV matched to Co-60 at 1332.5 keV with confidence 0.96
# Isotope Co-60 identified with 50.00% of peaks matched
#                                        filename  \
# 0  Daten/2016-11-30_10-25-23_Summenspektrum.txt
#
#                                                 data  \
# 0        energy in keV  counts
# 0             -0.4...
#
#                         peaks  \
# 0  [8, 425, 2277, 4037, 4584]
#
#                                           properties  \
# 0  {'prominences': [76908.0, 1066.0, 22617.0, 791...
#
#                                calculated_polynomial  \
# 0  [1.8877155171219202, 122.99763937885626, 661.1...
#
#                                         fitted_peaks  \
# 0  [1.77+/-0.31, 122+/-4, 661.1+/-0.7, 1172.9+/-0...
#
#                                    fitted_peaks_mean  \
# 0  [1.7745897065383576, 122.48829752313193, 661.1...
#
#                                     fitted_peaks_std     identified_isotopes  \
# 0  [0.312774846656637, 3.560845057506345, 0.73383...  [Cs-137, Co-60, Co-60]
#
#                                          confidences          matched  \
# 0  [0.9050071127790248, 0.912774333110177, 0.9218...  [1.0, 0.5, 0.5]
#
#                                    total_confidences
# 0  [0.9050071127790248, 0.4563871665550885, 0.460...

# %%
plot_spectrum_from_file('Daten/2016-11-30_10-25-23_Summenspektrum.txt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_spectrum('Daten/2016-11-30_10-25-23_Summenspektrum.txt')
#
# File ~\Documents\Arbeit\gammaspectroscopy\src\utils.py:149, in plot_spectrum(df)
#     148 def plot_spectrum(df: pd.DataFrame):
# --> 149     df['data'].plot(x='energy in keV', y='counts', kind='hist', figsize=(10, 6))
#     150     plt.xlabel('Energy (keV)')
#     151     plt.ylabel('Counts')
#
# TypeError: string indices must be integers

# %%
files = glob('Daten/*.txt')
len(files)
# Out:
# 1246

# %%
results_df = pd.concat([process_spectrum(file, prominence=500) for file in files], ignore_index=True)
results_df.head()
# Out:
#                                           filename  \
# 0     Daten\2016-11-21_09-27-54_Summenspektrum.txt
# 1     Daten\2016-11-24_07-16-40_Summenspektrum.txt
# 2     Daten\2016-11-25_12-59-15_Summenspektrum.txt
# 3     Daten\2016-11-28_07-17-31_Summenspektrum.txt
# 4     Daten\2016-11-29_08-48-54_Summenspektrum.txt
# ...                                            ...
# 1241  Daten\2024-09-26_07-09-35_Summenspektrum.txt
# 1242  Daten\2024-09-27_07-18-35_Summenspektrum.txt
# 1243  Daten\2024-09-30_07-57-21_Summenspektrum.txt
# 1244  Daten\2024-10-01_07-53-29_Summenspektrum.txt
# 1245  Daten\2024-10-02_07-37-57_Summenspektrum.txt
#
#                                                    data  \
# 0           energy in keV  counts
# 0             -0.4...
# 1           energy in keV  counts
# 0             -0.4...
# 2           energy in keV  counts
# 0             -0.4...
# 3           energy in keV  counts
# 0             -0.4...
# 4           energy in keV  counts
# 0             -0.4...
# ...                                                 ...
# 1241        energy in keV  counts
# 0             -0.1...
# 1242        energy in keV  counts
# 0             -0.3...
# 1243        energy in keV  counts
# 0             -0.3...
# 1244        energy in keV  counts
# 0             -0.3...
# 1245        energy in keV  counts
# 0             -0.3...
#
#                                      peaks  \
# 0                  [9, 18, 259, 293, 2278]
# 1     [7, 21, 33, 71, 259, 293, 393, 2278]
# 2                           [9, 259, 2277]
# 3                               [15, 2278]
# 4                            [8, 14, 2277]
# ...                                    ...
# 1241                                   [7]
# 1242                                   [7]
# 1243                                   [7]
# 1244                                   [7]
# 1245                                   [7]
#
#                                              properties  \
# 0     {'prominences': [3805.0, 11790.0, 1572.0, 613....
# 1     {'prominences': [19841.0, 3291.0, 990.0, 947.0...
# 2     {'prominences': [80362.0, 902.0, 4264.0], 'lef...
# 3     {'prominences': [5138.0, 1515.0], 'left_bases'...
# 4     {'prominences': [13403.0, 1794.0, 2469.0], 'le...
# ...                                                 ...
# 1241  {'prominences': [12674.0], 'left_bases': [0], ...
# 1242  {'prominences': [12205.0], 'left_bases': [0], ...
# 1243  {'prominences': [13717.0], 'left_bases': [0], ...
# 1244  {'prominences': [15388.0], 'left_bases': [1], ...
# 1245  {'prominences': [16380.0], 'left_bases': [0], ...
#
#                                   calculated_polynomial  \
# 0     [2.17812347791993, 4.79180021167972, 74.783660...
# 1     [1.59730766935897, 5.66302782423073, 9.1479484...
# 2     [2.17812347791993, 74.78366015242995, 661.1142...
# 3               [3.9205736164442504, 661.4048874141486]
# 4     [1.8877155171219202, 3.6301649774358804, 661.1...
# ...                                                 ...
# 1241                                 [1.59730766935897]
# 1242                                 [1.59730766935897]
# 1243                                 [1.59730766935897]
# 1244                                 [1.59730766935897]
# 1245                                 [1.59730766935897]
#
#                                            fitted_peaks  \
# 0     [2.2+/-0.5, 4.8+/-1.3, 74.7+/-1.5, 84.7+/-2.1,...
# 1     [1.65+/-0.29, 5.6+/-1.1, 9.1+/-1.9, 20+/-5, 74...
# 2                  [2.1+/-0.4, 74.7+/-1.2, 661.2+/-0.7]
# 3                              [3.8+/-1.2, 661.4+/-0.8]
# 4                [2.0+/-0.4, -0.44+/-0.29, 661.2+/-0.7]
# ...                                                 ...
# 1241                                      [1.73+/-0.33]
# 1242                                      [1.74+/-0.35]
# 1243                                      [1.72+/-0.35]
# 1244                                      [1.69+/-0.33]
# 1245                                      [1.69+/-0.34]
#
#                                       fitted_peaks_mean  \
# 0     [2.1949337017004584, 4.760360102175254, 74.747...
# 1     [1.6492874932310777, 5.569771912889466, 9.0775...
# 2     [2.1346609530456644, 74.65888630314258, 661.21...
# 3               [3.8037659790602976, 661.3662404003773]
# 4     [1.9739906729137935, -0.4355441, 661.216748045...
# ...                                                 ...
# 1241                                [1.728441610166713]
# 1242                                [1.744544938558834]
# 1243                                [1.722876201249561]
# 1244                               [1.6919035196010428]
# 1245                               [1.6941359909845002]
#
#                                        fitted_peaks_std identified_isotopes  \
# 0     [0.4716261301219222, 1.2607007423117536, 1.515...            [Cs-137]
# 1     [0.2915364489251179, 1.1288644265372403, 1.862...    [Tc-99m, Cs-137]
# 2     [0.3777388474551808, 1.2278336619783288, 0.742...            [Cs-137]
# 3              [1.1770141331605322, 0.7891301659332648]            [Cs-137]
# 4     [0.40350424822245456, 0.290407, 0.729150326590...            [Cs-137]
# ...                                                 ...                 ...
# 1241                               [0.3263001547939657]                  []
# 1242                              [0.34737700884165684]                  []
# 1243                               [0.3459508150054934]                  []
# 1244                              [0.33194257596543475]                  []
# 1245                               [0.3445114950467752]                  []
#
#                                   confidences     matched  \
# 0                        [0.9305318283386198]       [1.0]
# 1     [0.586786135440607, 0.8712443050163385]  [1.0, 1.0]
# 2                        [0.8076640758257452]       [1.0]
# 3                        [0.9144415378645031]       [1.0]
# 4                        [0.8028192632682709]       [1.0]
# ...                                       ...         ...
# 1241                                       []          []
# 1242                                       []          []
# 1243                                       []          []
# 1244                                       []          []
# 1245                                       []          []
#
#                             total_confidences
# 0                        [0.9305318283386198]
# 1     [0.586786135440607, 0.8712443050163385]
# 2                        [0.8076640758257452]
# 3                        [0.9144415378645031]
# 4                        [0.8028192632682709]
# ...                                       ...
# 1241                                       []
# 1242                                       []
# 1243                                       []
# 1244                                       []
# 1245                                       []
#
# [1246 rows x 12 columns]

# %%
results_df.drop(columns=['data', 'properties', 'fitted_peaks']).to_parquet('results_prominence_500.pq')

# %%
plot_spectrum(results_df.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_spectrum(results_df.iloc[0])
#
# NameError: name 'plot_spectrum' is not defined
