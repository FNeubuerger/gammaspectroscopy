# %%
from src.utils import *
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('results_prominence=500_rel_height=0.5_width=5_tolerance=0.7.pq')

# %%
df
# Out:
#                                           filename  \
# 0     Daten\2016-11-21_09-27-54_Summenspektrum.txt
# 1     Daten\2016-11-24_07-16-40_Summenspektrum.txt
# 2     Daten\2016-11-25_12-59-15_Summenspektrum.txt
# 3     Daten\2016-11-28_07-17-31_Summenspektrum.txt
# 4     Daten\2016-11-29_08-48-54_Summenspektrum.txt
# ...                                            ...
# 1241  Daten\2024-09-26_07-09-35_Summenspektrum.txt
# 1242  Daten\2024-09-27_07-18-35_Summenspektrum.txt
# 1243  Daten\2024-09-30_07-57-21_Summenspektrum.txt
# 1244  Daten\2024-10-01_07-53-29_Summenspektrum.txt
# 1245  Daten\2024-10-02_07-37-57_Summenspektrum.txt
#
#                                   peaks  \
# 0                  [18, 259, 293, 2278]
# 1     [21, 33, 71, 259, 293, 393, 2278]
# 2                           [259, 2277]
# 3                            [15, 2278]
# 4                                [2277]
# ...                                 ...
# 1241                                 []
# ...

# %%
df['num_isotopes'] = df['identified_isotopes'].apply(lambda x: len(x))
df[df['num_isotopes']==2].index
# Out:
# Index([1, 11, 14, 108, 163, 232, 234, 1032, 1193], dtype='int64')

# %%
plot_spectrum(df.iloc[108], semilogy=True)
# Out:
# C:\Users\felix\Documents\Arbeit\gammaspectroscopy\src\utils.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'] = df['filename'].replace('\\', '/')
# (8160, 2)
