# %%
import pandas as pd
import pdfplumber

# %%
pdf = pdfplumber.open("isotope_identification_table2.pdf")

# %%
page = pdf.pages[0]
im = page.to_image()
im

# %%
table = page.extract_table()
table

# %%
im.debug_tablefinder()
