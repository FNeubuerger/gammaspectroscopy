# %%
import pandas as pd
import os
# Print the current working directory
print(os.getcwd())
# Read the contents of the file into a pandas DataFrame
file_path = 'databasegamma.txt'
columns = ["Nuclide", "Energy (keV)", "Intensity (%)", "Decay mode",  "Half-life", "Effective Intens.(dps)"]

# Use error_bad_lines=False to skip lines with too many fields
df = pd.read_table(file_path, skiprows=25, names=columns, sep='\s+', on_bad_lines='skip', index_col=False)
df
# Out:
# C:\Users\felix\Documents\Arbeit\gammaspectroscopy
# C:\Users\felix\AppData\Local\Temp\ipykernel_13140\3630142957.py:10: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_table(file_path, skiprows=25, names=columns, sep='\s+', on_bad_lines='skip', index_col=False)
#         Nuclide Energy (keV) Intensity (%) Decay mode Half-life  \
# 0     65-Tb-156            X            --         IT      24.4
# 1     82-Pb-199            X            --         IT      12.2
# 2     90-Th-229         0.01            --         IT        --
# 3     52-Te-117           1.            --         IT       103
# 4     47-Ag-110         1.16            --         IT    249.76
# ...         ...          ...           ...        ...       ...
# 7440    39-Y-98       2941.3         16.67         B-     0.548
# 7441   21-Sc-41       2959.3          0.01         EC     596.3
# 7442   14-Si-27       2981.1          0.03         EC      4.16
# 7443    19-K-35      2982.67          50.8         EC       178
# 7444  59-Pr-132       2990.9          100.         EC       1.6
#
#      Effective Intens.(dps)
# 0                         H
# 1                         M
# 2                       NaN
# 3                        MS
# 4                         D
# ...                     ...
# 7440                      S
# 7441                     MS
# 7442                      S
# 7443                     MS
# 7444                      M
#
# [7445 rows x 6 columns]

# %%
df['Energy (keV)']
# Out:
# 0             X
# 1             X
# 2          0.01
# 3            1.
# 4          1.16
#          ...
# 7440     2941.3
# 7441     2959.3
# 7442     2981.1
# 7443    2982.67
# 7444     2990.9
# Name: Energy (keV), Length: 7445, dtype: object
